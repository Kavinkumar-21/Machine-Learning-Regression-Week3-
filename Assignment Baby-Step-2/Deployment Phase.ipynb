# %%
#required Libraries for Deployment

import pickle

# %%
#Load the saved model and validate the value parameters

loaded_model = pickle.load(open("Finalized_Model_LinearRegression.sav","rb"))
result = loaded_model.predict([[15]])
result
# Out:
# C:\Users\kavvi\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[167181.3106341]])
